# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist_ = input_data.read_data_sets("/tmp/data/", one_hot = True)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-a729620180fb>", line 1, in <module>
#     from tensorflow.examples.tutorials.mnist import input_data
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\examples\tutorials\mnist\__init__.py", line 21, in <module>
#     from tensorflow.examples.tutorials.mnist import input_data
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\examples\tutorials\mnist\input_data.py", line 30, in <module>
#     from tensorflow.contrib.learn.python.learn.datasets.mnist import read_data_sets
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\contrib\__init__.py", line 39, in <module>
#     from tensorflow.contrib import compiler
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\contrib\compiler\__init__.py", line 21, in <module>
#     from tensorflow.contrib.compiler import jit
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\contrib\compiler\__init__.py", line 22, in <module>
#     from tensorflow.contrib.compiler import xla
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\contrib\compiler\xla.py", line 22, in <module>
#     from tensorflow.python.estimator import model_fn as model_fn_lib
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\python\estimator\model_fn.py", line 26, in <module>
#     from tensorflow_estimator.python.estimator import model_fn
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_estimator\python\estimator\model_fn.py", line 29, in <module>
#     from tensorflow.python.types import core
# ModuleNotFoundError: No module named 'tensorflow.python.types'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ModuleNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 953, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-a729620180fb>", line 1, in <module>
#     from tensorflow.examples.tutorials.mnist import input_data
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\examples\tutorials\mnist\__init__.py", line 21, in <module>
#     from tensorflow.examples.tutorials.mnist import input_data
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\examples\tutorials\mnist\input_data.py", line 30, in <module>
#     from tensorflow.contrib.learn.python.learn.datasets.mnist import read_data_sets
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\contrib\__init__.py", line 39, in <module>
#     from tensorflow.contrib import compiler
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\contrib\compiler\__init__.py", line 21, in <module>
#     from tensorflow.contrib.compiler import jit
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\contrib\compiler\__init__.py", line 22, in <module>
#     from tensorflow.contrib.compiler import xla
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\contrib\compiler\xla.py", line 22, in <module>
#     from tensorflow.python.estimator import model_fn as model_fn_lib
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\python\estimator\model_fn.py", line 26, in <module>
#     from tensorflow_estimator.python.estimator import model_fn
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_estimator\python\estimator\model_fn.py", line 29, in <module>
#     from tensorflow.python.types import core
# ModuleNotFoundError: No module named 'tensorflow.python.types'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ModuleNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 953, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-a729620180fb>", line 1, in <module>
#     from tensorflow.examples.tutorials.mnist import input_data
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\examples\tutorials\mnist\__init__.py", line 21, in <module>
#     from tensorflow.examples.tutorials.mnist import input_data
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\examples\tutorials\mnist\input_data.py", line 30, in <module>
#     from tensorflow.contrib.learn.python.learn.datasets.mnist import read_data_sets
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\contrib\__init__.py", line 39, in <module>
#     from tensorflow.contrib import compiler
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\contrib\compiler\__init__.py", line 21, in <module>
#     from tensorflow.contrib.compiler import jit
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\contrib\compiler\__init__.py", line 22, in <module>
#     from tensorflow.contrib.compiler import xla
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\contrib\compiler\xla.py", line 22, in <module>
#     from tensorflow.python.estimator import model_fn as model_fn_lib
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_core\python\estimator\model_fn.py", line 26, in <module>
#     from tensorflow_estimator.python.estimator import model_fn
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow_estimator\python\estimator\model_fn.py", line 29, in <module>
#     from tensorflow.python.types import core
# ModuleNotFoundError: No module named 'tensorflow.python.types'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ModuleNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 3282, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 1211, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\chunc\anaconda3\envs\tensorflow_v1\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 953, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist

#Importing data
(x_train, y_train), (x_test, y_test) = mnist.load_data()
image_vector_size = 28*28

#Normalization
x_train = x_train.astype(float) / 255.
x_test = x_test.astype(float) / 255.

#Flattening Feature
x_train = x_train.reshape(x_train.shape[0], image_vector_size)
x_test = x_test.reshape(x_test.shape[0], image_vector_size)

#Converting Target variable from scaler to softmax class
import keras
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
#Parameters
learning_rate = 0.001
training_epochs = 20
N = 784
n_hidden_1 = 392 # N/2
n_hidden_2 = 196 # N/4
n_input = N
n_classes = 10
batch_size = 100
x = tf.placeholder("float",[None,n_input])
y = tf.placeholder("float",[None,n_classes])

# %%
# 1st Hidden Layer
weight_hidden_1 = tf.Variable(tf.random_normal([n_input,n_hidden_1]))
bias_hidden_1   = tf.Variable(tf.random_normal([n_hidden_1]))
output_hidden_1 = tf.nn.relu(tf.add(tf.matmul(x,weight_hidden_1),bias_hidden_1))

# %%
#2nd Hidden Layer
weight_hidden_2 = tf.Variable(tf.random_normal([n_hidden_1,n_hidden_2]))
bias_hidden_2   = tf.Variable(tf.random_normal([n_hidden_2]))
output_hidden_2 = tf.nn.sigmoid(tf.add(tf.matmul(output_hidden_1,weight_hidden_2),bias_hidden_2))

# %%
#Output Layer
weight_output = tf.Variable(tf.random_normal([n_hidden_2,n_classes]))
bias_output   = tf.Variable(tf.random_normal([n_classes]))
final_output  = tf.matmul(output_hidden_2,weight_output) + bias_output

# %%
#Loss Function = (y - y_pred)^2 / size
# loss = tf.reduce_mean(tf.math.squared_difference(y,tf.nn.softmax(final_output)))

# %%
#Loss Function = (y - y_pred)^4/size
# loss = tf.reduce_mean((y - tf.nn.softmax(final_output))**4)

# %%
loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(
   logits = final_output, labels = y))

# %%
#Error function
error = tf.reduce_mean(tf.math.squared_difference(y,tf.nn.softmax(final_output)))

# %%
activated_output = tf.nn.softmax(final_output)

# %%
#Optimizer
optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(loss)
correct_prediction = tf.equal(tf.argmax(tf.nn.softmax(final_output), 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))

# %%
#Brute Force Meathod - 
init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)    
    for epoch in range(training_epochs):        
        print(epoch)        
        for i in range(100):            
            sess.run(optimizer,feed_dict={
                x: x_train,
                y: y_train
            }) 
        correct_prediction = tf.equal(tf.argmax(final_output, 1), tf.argmax(y, 1))       
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float")) 
        print("Model Accuracy:", accuracy.eval({x: x_test, y: y_test}))
    correct_prediction = tf.equal(tf.argmax(final_output, 1), tf.argmax(y, 1))       
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float")) 
    print("Model Accuracy:", accuracy.eval({x: x_test, y: y_test}))
# Out:
# 0
# Model Accuracy: 0.5752
# 1
# Model Accuracy: 0.7377
# 2
# Model Accuracy: 0.7881
# 3
# Model Accuracy: 0.8142
# 4
# Model Accuracy: 0.8279
# 5
# Model Accuracy: 0.8391
# 6
# Model Accuracy: 0.8486
# 7
# Model Accuracy: 0.8545
# 8
# Model Accuracy: 0.8619
# 9
# Model Accuracy: 0.8656
# 10
# Model Accuracy: 0.8692
# 11
# Model Accuracy: 0.8719
# 12
# Model Accuracy: 0.8748
# 13
# Model Accuracy: 0.8784
# 14
# Model Accuracy: 0.8815
# 15
# Model Accuracy: 0.8834
# 16
# Model Accuracy: 0.885
# 17
# Model Accuracy: 0.8864
# 18
# Model Accuracy: 0.888
# 19
# Model Accuracy: 0.8895
# Model Accuracy: 0.8895

# %%
#Graph starting
init = tf.global_variables_initializer()
mse_loss_list = []
epoch_list = []
with tf.Session() as sess:
    
    sess.run(init)    
    for epoch in range(100):                  
        
        print(epoch)
        avg_cost = 0. 
        total_batch = int(mnist_.train.num_examples / batch_size)             
        for i in range(total_batch):             
            batch_xs, batch_ys = mnist_.train.next_batch(batch_size)          
            sess.run(optimizer, feed_dict = {
            x: batch_xs, y: batch_ys})
        
        
        correct_prediction = tf.equal(tf.argmax(final_output, 1), tf.argmax(y, 1))       
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float")) 
        print("Model Accuracy:", accuracy.eval({x: x_test, y: y_test}))
        
        mse_loss_list.append(sess.run(error,feed_dict={
            x: mnist_.test.images, y: mnist_.test.labels
        }))
        epoch_list.append(epoch+1)
        
    correct_prediction = tf.equal(tf.argmax(final_output, 1), tf.argmax(y, 1))       
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float")) 
    print("Model Accuracy:", accuracy.eval({x: mnist_.test.images, y: mnist_.test.labels}))
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 164
# 0
# Model Accuracy: 0.7407
# 1
# Model Accuracy: 0.8181
# 2
# Model Accuracy: 0.8579
# 3
# Model Accuracy: 0.88
# 4
# Model Accuracy: 0.8938
# 5
# Model Accuracy: 0.9044
# 6
# Model Accuracy: 0.912
# 7
# Model Accuracy: 0.918
# 8
# Model Accuracy: 0.9214
# 9
# Model Accuracy: 0.9269
# 10
# Model Accuracy: 0.9301
# 11
# Model Accuracy: 0.9325
# 12
# Model Accuracy: 0.9367
# 13
# Model Accuracy: 0.9374
# 14
# Model Accuracy: 0.941
# 15
# Model Accuracy: 0.9428
# 16
# Model Accuracy: 0.9433
# 17
# Model Accuracy: 0.9473
# 18
# Model Accuracy: 0.9468
# 19
# Model Accuracy: 0.9508
# 20
# Model Accuracy: 0.9511
# 21
# Model Accuracy: 0.9521
# 22
# Model Accuracy: 0.9534
# 23
# Model Accuracy: 0.9533
# 24
# Model Accuracy: 0.9539
# 25
# Model Accuracy: 0.9565
# 26
# Model Accuracy: 0.9556
# 27
# Model Accuracy: 0.9545
# 28
# Model Accuracy: 0.958
# 29
# Model Accuracy: 0.9568
# 30
# Model Accuracy: 0.9574
